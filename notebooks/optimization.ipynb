# %% [markdown]
# # Optimization

# %%
import pandas as pd
import os

# %%
# Read the distances matrix
df_matrix = pd.read_csv('../data/df_matrix.csv', index_col="ori")
df_matrix.head(3)
# Out:
#                                         Estació del Nord  \
# ori
# Estació del Nord                                     0.0
# Falla Almirante Cadarso-Conde de Altea            1085.7
# Falla Arzobispo Olaechea-San Marcelino            4034.5
#
#                                         Falla Almirante Cadarso-Conde de Altea  \
# ori
# Estació del Nord                                                        2221.8
# Falla Almirante Cadarso-Conde de Altea                                     0.0
# Falla Arzobispo Olaechea-San Marcelino                                  4625.3
#
#                                         Falla Arzobispo Olaechea-San Marcelino  \
# ori
# Estació del Nord                                                        4124.1
# Falla Almirante Cadarso-Conde de Altea                                  5863.4
# Falla Arzobispo Olaechea-San Marcelino                                     0.0
#
#                                         Falla Conde de Salvatierra-Cirilo Amorós-Mercat de Colón  \
# ori
# Estació del Nord                                                                   1390.6
# Falla Almirante Cadarso-Conde de Altea                                              413.3
# Falla Arzobispo Olaechea-San Marcelino                                             4814.5
#
#                                         Falla Convento Jerusalén-Matemático Marzal  \
# ori
# Estació del Nord                                                             574.9
# Falla Almirante Cadarso-Conde de Altea                                      1632.2
# Falla Arzobispo Olaechea-San Marcelino                                      3560.3
#
#                                         Falla Cuba-Literato Azorín  \
# ori
# Estació del Nord                                            3100.0
# Falla Almirante Cadarso-Conde de Altea                      1932.6
# Falla Arzobispo Olaechea-San Marcelino                      3633.2
#
#                                         Falla Císcar-Burriana  \
# ori
# Estació del Nord                                       2457.8
# Falla Almirante Cadarso-Conde de Altea                  422.7
# Falla Arzobispo Olaechea-San Marcelino                 4861.4
#
#                                         Falla Duc de Gaeta-Pobla de Farnals  \
# ori
# Estació del Nord                                                     4504.7
# Falla Almirante Cadarso-Conde de Altea                               2507.1
# Falla Arzobispo Olaechea-San Marcelino                               6457.8
#
#                                         Falla Espartero-Ramón y Cajal  \
# ori
# Estació del Nord                                               1249.7
# Falla Almirante Cadarso-Conde de Altea                         2335.4
# Falla Arzobispo Olaechea-San Marcelino                         3786.9
#
#                                         Falla Exposición-Misser Mascó  ...  \
# ori                                                                    ...
# Estació del Nord                                               3922.9  ...
# Falla Almirante Cadarso-Conde de Altea                         1925.3  ...
# Falla Arzobispo Olaechea-San Marcelino                         7445.6  ...
#
#                                         Falla Plaza del Mercado Central  \
# ori
# Estació del Nord                                                 1439.6
# Falla Almirante Cadarso-Conde de Altea                           2525.3
# Falla Arzobispo Olaechea-San Marcelino                           4730.8
#
#                                         Falla Plaza del Pilar  \
# ori
# Estació del Nord                                        836.4
# Falla Almirante Cadarso-Conde de Altea                 1922.1
# Falla Arzobispo Olaechea-San Marcelino                 4127.6
#
#                                         Falla Quart-Extramurs-Velázquez  \
# ori
# Estació del Nord                                                 3081.4
# Falla Almirante Cadarso-Conde de Altea                           4167.0
# Falla Arzobispo Olaechea-San Marcelino                           4411.4
#
#                                         Falla Quart-Palomar  \
# ori
# Estació del Nord                                     1518.8
# Falla Almirante Cadarso-Conde de Altea               2604.4
# Falla Arzobispo Olaechea-San Marcelino               4810.0
#
#                                         Falla Regne de Valencia-Duque de Calabria  \
# ori
# Estació del Nord                                                           2272.8
# Falla Almirante Cadarso-Conde de Altea                                      667.5
# Falla Arzobispo Olaechea-San Marcelino                                     4676.4
#
#                                         Falla Reina-Paz-San Vicente (Falla Tio Pep)  \
# ori
# Estació del Nord                                                              942.0
# Falla Almirante Cadarso-Conde de Altea                                       2027.6
# Falla Arzobispo Olaechea-San Marcelino                                       4392.3
#
#                                         Falla Ribera-Convento Santa Clara  \
# ori
# Estació del Nord                                                    359.1
# Falla Almirante Cadarso-Conde de Altea                             1444.8
# Falla Arzobispo Olaechea-San Marcelino                             3809.4
#
#                                         Falla San Vicente-Periodista Azzati  \
# ori
# Estació del Nord                                                      642.1
# Falla Almirante Cadarso-Conde de Altea                               1727.7
# Falla Arzobispo Olaechea-San Marcelino                               4092.4
#
#                                         Falla Santa Genoveva Torres-Arquitecte Tolsà (la Nova de Orriols)  \
# ori
# Estació del Nord                                                                   4866.0
# Falla Almirante Cadarso-Conde de Altea                                             4597.0
# Falla Arzobispo Olaechea-San Marcelino                                             8815.9
#
#                                         Falla Sueca-Literato Azorín
# ori
# Estació del Nord                                             3176.9
# Falla Almirante Cadarso-Conde de Altea                       2009.5
# Falla Arzobispo Olaechea-San Marcelino                       3710.1
#
# [3 rows x 31 columns]

# %%
# Read the routes df
df_routes = pd.read_csv('../data/df_routes.csv')
df_routes
# Out:
#                                                    ori  \
# 0           Falla Convento Jerusalén-Matemático Marzal
# 1           Falla Convento Jerusalén-Matemático Marzal
# 2           Falla Convento Jerusalén-Matemático Marzal
# 3           Falla Convento Jerusalén-Matemático Marzal
# 4           Falla Convento Jerusalén-Matemático Marzal
# ..                                                 ...
# 865  Falla Santa Genoveva Torres-Arquitecte Tolsà (...
# 866  Falla Santa Genoveva Torres-Arquitecte Tolsà (...
# 867  Falla Santa Genoveva Torres-Arquitecte Tolsà (...
# 868  Falla Santa Genoveva Torres-Arquitecte Tolsà (...
# 869  Falla Santa Genoveva Torres-Arquitecte Tolsà (...
#
#                                                des  osrm_dist  \
# 0                       Falla Cuba-Literato Azorín     3154.6
# 1                      Falla Sueca-Literato Azorín     3231.5
# 2           Falla Almirante Cadarso-Conde de Altea     2276.4
# 3                                 Falla Na Jordana     2410.0
# 4                            Falla Plaza del Pilar     1120.1
# ..                                             ...        ...
# 865         Falla Arzobispo Olaechea-San Marcelino     8625.0
# 866          Falla Justo Vilar-Mercado del Cabañal     5475.1
# 867      Falla Islas Canarias-Trafalgar-Samuel Ros     4850.7
# 868              Falla Ribera-Convento Santa Clara     5343.8
# 869  Falla Jerónima Galés-Litógrafo Pascual y Abad     7295.3
#
#                                               geometry
# 0    [[-0.379878, 39.466528], [-0.379727, 39.466493...
# 1    [[-0.379878, 39.466528], [-0.379727, 39.466493...
# 2    [[-0.379878, 39.466528], [-0.379727, 39.466493...
# 3    [[-0.379878, 39.466528], [-0.379727, 39.466493...
# 4    [[-0.379878, 39.466528], [-0.379727, 39.466493...
# ..                                                 ...
# 865  [[-0.366265, 39.492586], [-0.366185, 39.492525...
# 866  [[-0.366265, 39.492586], [-0.366185, 39.492525...
# 867  [[-0.366265, 39.492586], [-0.366185, 39.492525...
# 868  [[-0.366265, 39.492586], [-0.366185, 39.492525...
# 869  [[-0.366265, 39.492586], [-0.366185, 39.492525...
#
# [870 rows x 4 columns]

# %%
"""Simple Travelling Salesperson Problem (TSP) between cities."""

from ortools.constraint_solver import routing_enums_pb2
from ortools.constraint_solver import pywrapcp


def create_data_model():
    """Stores the data for the problem."""
    data = {}
    data["distance_matrix"] = df_matrix.round(0).astype(int).values.tolist()
    data["num_vehicles"] = 1
    data["depot"] = 0
    return data


def print_solution(manager, routing, solution):
    sol = []
    """Prints solution on console."""
    print(f"Objective: {solution.ObjectiveValue()} miles")
    index = routing.Start(0)
    plan_output = "Route for vehicle 0:\n"
    route_distance = 0
    while not routing.IsEnd(index):
        plan_output += f" {manager.IndexToNode(index)} ->"
        sol.append(manager.IndexToNode(index))
        previous_index = index
        index = solution.Value(routing.NextVar(index))
        route_distance += routing.GetArcCostForVehicle(previous_index, index, 0)
    plan_output += f" {manager.IndexToNode(index)}\n"
    print(plan_output)
    plan_output += f"Route distance: {route_distance}meters\n"

def get_routes(solution, routing, manager):
    """Get vehicle routes from a solution and store them in an array."""
    # Get vehicle routes and store them in a two dimensional array whose
    # i,j entry is the jth location visited by vehicle i along its route.
    routes = []
    for route_nbr in range(routing.vehicles()):
        index = routing.Start(route_nbr)
        route = [manager.IndexToNode(index)]
        while not routing.IsEnd(index):
            index = solution.Value(routing.NextVar(index))
            route.append(manager.IndexToNode(index))
            
        routes.append(route)
    return routes



def optimize_tsp():
    """Entry point of the program."""
    # Instantiate the data problem.
    data = create_data_model()

    # Create the routing index manager.
    manager = pywrapcp.RoutingIndexManager(
        len(data["distance_matrix"]), data["num_vehicles"], data["depot"]
    )

    # Create Routing Model.
    routing = pywrapcp.RoutingModel(manager)


    def distance_callback(from_index, to_index):
        """Returns the distance between the two nodes."""
        # Convert from routing variable Index to distance matrix NodeIndex.
        from_node = manager.IndexToNode(from_index)
        to_node = manager.IndexToNode(to_index)
        return data["distance_matrix"][from_node][to_node]

    transit_callback_index = routing.RegisterTransitCallback(distance_callback)

    # Define cost of each arc.
    routing.SetArcCostEvaluatorOfAllVehicles(transit_callback_index)

    # Setting first solution heuristic.
    search_parameters = pywrapcp.DefaultRoutingSearchParameters()
    search_parameters.first_solution_strategy = (
        routing_enums_pb2.FirstSolutionStrategy.PATH_CHEAPEST_ARC
    )

    # Solve the problem.
    solution = routing.SolveWithParameters(search_parameters)

    # Print solution on console.
    if solution:
        print_solution(manager, routing, solution)
        return get_routes(solution, routing, manager)

# %%
sol = optimize_tsp()[0]
# Out:
# Objective: 44233 miles
# Route for vehicle 0:
#  0 -> 22 -> 26 -> 21 -> 19 -> 24 -> 15 -> 20 -> 28 -> 13 -> 2 -> 5 -> 30 -> 25 -> 6 -> 16 -> 1 -> 3 -> 11 -> 9 -> 7 -> 12 -> 14 -> 17 -> 29 -> 10 -> 18 -> 23 -> 8 -> 4 -> 27 -> 0

# %%
# optimized_sequence 
optimized_sequence = list(df_matrix.index[sol])
optimized_sequence = [[optimized_sequence[i],optimized_sequence[i+1]]  for i in range(len(optimized_sequence)-1)]
optimized_sequence
# Out:
# [['Estació del Nord', 'Falla Plaza del Pilar'],
#  ['Falla Plaza del Pilar', 'Falla Reina-Paz-San Vicente (Falla Tio Pep)'],
#  ['Falla Reina-Paz-San Vicente (Falla Tio Pep)',
#   'Falla Plaza del Mercado Central'],
#  ['Falla Plaza del Mercado Central', 'Falla Na Jordana'],
#  ['Falla Na Jordana', 'Falla Quart-Palomar'],
#  ['Falla Quart-Palomar', 'Falla Llanterna-Na Rovella-Avda. de l’Oest'],
#  ['Falla Llanterna-Na Rovella-Avda. de l’Oest', 'Falla Plaza de la Merced'],
#  ['Falla Plaza de la Merced', 'Falla San Vicente-Periodista Azzati'],
#  ['Falla San Vicente-Periodista Azzati',
#   'Falla Jerónima Galés-Litógrafo Pascual y Abad'],
#  ['Falla Jerónima Galés-Litógrafo Pascual y Abad',
#   'Falla Arzobispo Olaechea-San Marcelino'],
#  ['Falla Arzobispo Olaechea-San Marcelino', 'Falla Cuba-Literato Azorín'],
#  ['Falla Cuba-Literato Azorín', 'Falla Sueca-Literato Azorín'],
#  ['Falla Sueca-Literato Azorín', 'Falla Regne de Valencia-Duque de Calabria'],
#  ['Falla Regne de Valencia-Duque de Calabria', 'Falla Císcar-Burriana'],
#  ['Falla Císcar-Burriana', 'Falla Maestro Gozalbo-Conde de Altea'],
#  ['Falla Maestro Gozalbo-Conde de Altea',
#   'Falla Almirante Cadarso-Conde de Altea'],
#  ['Falla Almirante Cadarso-Conde de Altea',
#   'Falla Conde de Salvatierra-Cirilo Amorós-Mercat de Colón'],
#  ['Falla Conde de Salvatierra-Cirilo Amorós-Mercat de Colón',
#   'Falla Grabador Esteve-Cirilo Amorós'],
#  ['Falla Grabador Esteve-Cirilo Amorós', 'Falla Exposición-Misser Mascó'],
#  ['Falla Exposición-Misser Mascó', 'Falla Duc de Gaeta-Pobla de Farnals'],
#  ['Falla Duc de Gaeta-Pobla de Farnals',
#   'Falla Islas Canarias-Trafalgar-Samuel Ros'],
#  ['Falla Islas Canarias-Trafalgar-Samuel Ros',
#   'Falla Justo Vilar-Mercado del Cabañal'],
#  ['Falla Justo Vilar-Mercado del Cabañal', 'Falla Malvarrosa-Ponz-Cavite'],
#  ['Falla Malvarrosa-Ponz-Cavite',
#   'Falla Santa Genoveva Torres-Arquitecte Tolsà (la Nova de Orriols)'],
#  ['Falla Santa Genoveva Torres-Arquitecte Tolsà (la Nova de Orriols)',
#   'Falla Gayano Lluch'],
#  ['Falla Gayano Lluch',
#   'Falla Monestir de Poblet – Aparicio Albiñana (L’Antiga de Campanar)'],
#  ['Falla Monestir de Poblet – Aparicio Albiñana (L’Antiga de Campanar)',
#   'Falla Quart-Extramurs-Velázquez'],
#  ['Falla Quart-Extramurs-Velázquez', 'Falla Espartero-Ramón y Cajal'],
#  ['Falla Espartero-Ramón y Cajal',
#   'Falla Convento Jerusalén-Matemático Marzal'],
#  ['Falla Convento Jerusalén-Matemático Marzal',
#   'Falla Ribera-Convento Santa Clara'],
#  ['Falla Ribera-Convento Santa Clara', 'Estació del Nord']]

# %%
df_routes_opt = pd.DataFrame(columns=df_routes.columns)
for seq in optimized_sequence:
    df_line = df_routes.loc[df_routes.ori.eq(seq[0]) & df_routes.des.eq(seq[1])]
    df_routes_opt = pd.concat([df_routes_opt,df_line])

df_routes_opt.reset_index(drop=True, inplace=True)
df_routes_opt
# Out:
# /var/folders/8c/_kn82sm11xg_1xzyn7clzt1w0000gn/T/ipykernel_96951/927058643.py:4: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_routes_opt = pd.concat([df_routes_opt,df_line])
#                                                   ori  \
# 0                               Falla Plaza del Pilar
# 1         Falla Reina-Paz-San Vicente (Falla Tio Pep)
# 2                     Falla Plaza del Mercado Central
# 3                                    Falla Na Jordana
# 4                                 Falla Quart-Palomar
# 5          Falla Llanterna-Na Rovella-Avda. de l’Oest
# 6                            Falla Plaza de la Merced
# 7                 Falla San Vicente-Periodista Azzati
# 8       Falla Jerónima Galés-Litógrafo Pascual y Abad
# 9              Falla Arzobispo Olaechea-San Marcelino
# 10                         Falla Cuba-Literato Azorín
# 11                        Falla Sueca-Literato Azorín
# 12          Falla Regne de Valencia-Duque de Calabria
# 13                              Falla Císcar-Burriana
# 14               Falla Maestro Gozalbo-Conde de Altea
# 15             Falla Almirante Cadarso-Conde de Altea
# 16  Falla Conde de Salvatierra-Cirilo Amorós-Merca...
# 17                Falla Grabador Esteve-Cirilo Amorós
# 18                      Falla Exposición-Misser Mascó
# 19                Falla Duc de Gaeta-Pobla de Farnals
# 20          Falla Islas Canarias-Trafalgar-Samuel Ros
# 21              Falla Justo Vilar-Mercado del Cabañal
# 22                       Falla Malvarrosa-Ponz-Cavite
# 23  Falla Santa Genoveva Torres-Arquitecte Tolsà (...
# 24                                 Falla Gayano Lluch
# 25  Falla Monestir de Poblet – Aparicio Albiñana (...
# 26                    Falla Quart-Extramurs-Velázquez
# 27                      Falla Espartero-Ramón y Cajal
# 28         Falla Convento Jerusalén-Matemático Marzal
#
#                                                   des  osrm_dist  \
# 0         Falla Reina-Paz-San Vicente (Falla Tio Pep)     1270.2
# 1                     Falla Plaza del Mercado Central      540.7
# 2                                    Falla Na Jordana     1311.7
# 3                                 Falla Quart-Palomar     1242.1
# 4          Falla Llanterna-Na Rovella-Avda. de l’Oest      813.1
# 5                            Falla Plaza de la Merced       39.0
# 6                 Falla San Vicente-Periodista Azzati      619.2
# 7       Falla Jerónima Galés-Litógrafo Pascual y Abad     2543.8
# 8              Falla Arzobispo Olaechea-San Marcelino     1368.3
# 9                          Falla Cuba-Literato Azorín     3633.2
# 10                        Falla Sueca-Literato Azorín      720.0
# 11          Falla Regne de Valencia-Duque de Calabria     1024.4
# 12                              Falla Císcar-Burriana      563.1
# 13               Falla Maestro Gozalbo-Conde de Altea      639.1
# 14             Falla Almirante Cadarso-Conde de Altea      540.1
# 15  Falla Conde de Salvatierra-Cirilo Amorós-Merca...      413.3
# 16                Falla Grabador Esteve-Cirilo Amorós     1127.2
# 17                      Falla Exposición-Misser Mascó     1492.4
# 18                Falla Duc de Gaeta-Pobla de Farnals     1838.4
# 19          Falla Islas Canarias-Trafalgar-Samuel Ros      925.4
# 20              Falla Justo Vilar-Mercado del Cabañal     2036.3
# 21                       Falla Malvarrosa-Ponz-Cavite     2843.1
# 22  Falla Santa Genoveva Torres-Arquitecte Tolsà (...     5281.0
# 23                                 Falla Gayano Lluch     1812.6
# 24  Falla Monestir de Poblet – Aparicio Albiñana (...     2031.6
# 25                    Falla Quart-Extramurs-Velázquez     2237.1
# 26                      Falla Espartero-Ramón y Cajal     2846.1
# 27         Falla Convento Jerusalén-Matemático Marzal      751.6
# 28                  Falla Ribera-Convento Santa Clara      669.9
#
#                                              geometry
# 0   [[-0.383211, 39.471669], [-0.38311, 39.471683]...
# 1   [[-0.378759, 39.472202], [-0.378787, 39.472165...
# 2   [[-0.381235, 39.473774], [-0.381272, 39.473774...
# 3   [[-0.38001, 39.480319], [-0.379891, 39.479779]...
# 4   [[-0.387383, 39.475231], [-0.387917, 39.475135...
# 5    [[-0.383154, 39.472534], [-0.382703, 39.472571]]
# 6   [[-0.382703, 39.472571], [-0.38234, 39.472601]...
# 7   [[-0.380499, 39.469614], [-0.380673, 39.469371...
# 8   [[-0.394822, 39.451006], [-0.394844, 39.451], ...
# 9   [[-0.393309, 39.443346], [-0.392851, 39.44324]...
# 10  [[-0.376415, 39.459471], [-0.375585, 39.459823...
# 11  [[-0.376813, 39.460076], [-0.376031, 39.460412...
# 12  [[-0.366953, 39.46368], [-0.366923, 39.463676]...
# 13  [[-0.36793, 39.465201], [-0.36839, 39.465851],...
# 14  [[-0.371921, 39.46526], [-0.371633, 39.46483],...
# 15  [[-0.368475, 39.465815], [-0.36839, 39.465851]...
# 16  [[-0.370488, 39.468827], [-0.371051, 39.469611...
# 17  [[-0.369433, 39.469376], [-0.369121, 39.468928...
# 18  [[-0.36188, 39.475256], [-0.361933, 39.475271]...
# 19  [[-0.351278, 39.468592], [-0.351427, 39.468231...
# 20  [[-0.349242, 39.463727], [-0.349429, 39.46335]...
# 21  [[-0.335728, 39.46701], [-0.335414, 39.466918]...
# 22  [[-0.330925, 39.481089], [-0.331077, 39.480403...
# 23  [[-0.366265, 39.492586], [-0.366185, 39.492525...
# 24  [[-0.382982, 39.492747], [-0.383104, 39.493083...
# 25  [[-0.397088, 39.483926], [-0.396998, 39.483797...
# 26  [[-0.407345, 39.472864], [-0.407455, 39.472843...
# 27  [[-0.385021, 39.468205], [-0.384525, 39.468815...
# 28  [[-0.379878, 39.466528], [-0.379727, 39.466493...

# %%
# df_routes_opt.to_csv('data/df_routes_opt.csv', index=False)
