# %%
# Load libraries
import pandas as pd

# %%
# Load datasets
df_routes = pd.read_csv('data/df_routes_opt.csv')
df_routes.head()
# Out:
#                                                  ori  \
# 0                                          Casa Luis
# 1                                 Falla Gayano Lluch
# 2  Falla Monestir de Poblet – Aparicio Albiñana (...
# 3                    Falla Quart-Extramurs-Velázquez
# 4                                   Falla Na Jordana
#
#                                                  des  osrm_dist  \
# 0                                 Falla Gayano Lluch      714.8
# 1  Falla Monestir de Poblet – Aparicio Albiñana (...     2031.6
# 2                    Falla Quart-Extramurs-Velázquez     2237.1
# 3                                   Falla Na Jordana     2757.2
# 4        Falla Reina-Paz-San Vicente (Falla Tio Pep)     1193.6
#
#                                       route_geometry
# 0  [[-0.379272, 39.488647], [-0.379316, 39.488637...
# 1  [[-0.382982, 39.492747], [-0.383104, 39.493083...
# 2  [[-0.397088, 39.483926], [-0.396998, 39.483797...
# 3  [[-0.407345, 39.472864], [-0.407455, 39.472843...
# 4  [[-0.38001, 39.480319], [-0.379891, 39.479779]...

# %%
df_fallas = pd.read_csv('data/fallas.csv')
df_fallas.head()
# Out:
#                                         Falla  \
# 0  Falla Convento Jerusalén-Matemático Marzal
# 1                  Falla Cuba-Literato Azorín
# 2                 Falla Sueca-Literato Azorín
# 3      Falla Almirante Cadarso-Conde de Altea
# 4                            Falla Na Jordana
#
#                                               Enlace        lat       lon
# 0  https://www.google.com/maps/place/Falla+Conven...  39.466441 -0.379912
# 1  https://www.google.com/maps/place/Falla+Cuba+L...  39.459464 -0.376410
# 2  https://www.google.com/maps/place/Falla+Sueca+...  39.460148 -0.376865
# 3  https://www.google.com/maps/place/Falla+Almira...  39.465822 -0.368480
# 4  https://www.google.com/maps/place/Falla+Na+Jor...  39.480291 -0.380225

# %%
import geopandas as gpd
import pandas as pd
import ast
from shapely.geometry import LineString

# Clean and convert the route_geometry column into a Python list (coordinates)
def create_line_string(geometry_str):
    try:
        # Remove any unwanted characters or spaces before parsing
        geometry_str_clean = geometry_str.strip()
        
        # Check if the string starts and ends with square brackets (list format)
        if geometry_str_clean.startswith('[') and geometry_str_clean.endswith(']'):
            # Safely convert string to list of coordinates
            coords = ast.literal_eval(geometry_str_clean)
            # Create a LineString geometry from the coordinates
            return LineString(coords)
        else:
            raise ValueError(f"Invalid geometry format: {geometry_str}")
    except (ValueError, SyntaxError, TypeError) as e:
        print(f"Error processing geometry: {e}")
        return None  # Return None for invalid geometries

def df_to_gdf(df, route_geometry_col='route_geometry'):


    # Apply the function to create the 'geometry' column containing LineString geometries
    df['geometry'] = df['route_geometry'].apply(create_line_string)

    # Now convert the DataFrame to a GeoDataFrame
    gdf_routes = gpd.GeoDataFrame(df, geometry='geometry')

    # Set the coordinate reference system (CRS) if known (for example, EPSG:4326 for WGS84)
    gdf_routes.set_crs('EPSG:4326', allow_override=True, inplace=True)

    return gdf_routes.drop(columns=[route_geometry_col])

# Check the GeoDataFrame
gdf_routes = df_to_gdf(df_routes)
gdf_routes.head()
# Out:
#                                                  ori  \
# 0                                          Casa Luis
# 1                                 Falla Gayano Lluch
# 2  Falla Monestir de Poblet – Aparicio Albiñana (...
# 3                    Falla Quart-Extramurs-Velázquez
# 4                                   Falla Na Jordana
#
#                                                  des  osrm_dist  \
# 0                                 Falla Gayano Lluch      714.8
# 1  Falla Monestir de Poblet – Aparicio Albiñana (...     2031.6
# 2                    Falla Quart-Extramurs-Velázquez     2237.1
# 3                                   Falla Na Jordana     2757.2
# 4        Falla Reina-Paz-San Vicente (Falla Tio Pep)     1193.6
#
#                                             geometry
# 0  LINESTRING (-0.37927 39.48865, -0.37932 39.488...
# 1  LINESTRING (-0.38298 39.49275, -0.3831 39.4930...
# 2  LINESTRING (-0.39709 39.48393, -0.397 39.4838,...
# 3  LINESTRING (-0.40734 39.47286, -0.40746 39.472...
# 4  LINESTRING (-0.38001 39.48032, -0.37989 39.479...

# %% [markdown]
# # Sort the fallas coordinates

# %%
df_fallas = pd.merge(df_fallas, gdf_routes["ori"], left_on='Falla',right_on="ori", how="right")
df_fallas.reset_index(drop=True, inplace=True)
df_fallas.head()
# Out:
#                                                Falla  \
# 0                                          Casa Luis
# 1                                 Falla Gayano Lluch
# 2  Falla Monestir de Poblet – Aparicio Albiñana (...
# 3                    Falla Quart-Extramurs-Velázquez
# 4                                   Falla Na Jordana
#
#                                               Enlace        lat       lon  \
# 0  https://www.google.com/maps/place/Ayuntamiento...  39.488690 -0.379288
# 1  https://www.google.com/maps/place/Falla+Gayano...  39.492748 -0.382976
# 2  https://www.google.com/maps/place/Falla+Monest...  39.483891 -0.397193
# 3  https://www.google.com/maps/place/Associaci%C3...  39.472837 -0.407336
# 4  https://www.google.com/maps/place/Falla+Na+Jor...  39.480291 -0.380225
#
#                                                  ori
# 0                                          Casa Luis
# 1                                 Falla Gayano Lluch
# 2  Falla Monestir de Poblet – Aparicio Albiñana (...
# 3                    Falla Quart-Extramurs-Velázquez
# 4                                   Falla Na Jordana

# %% [markdown]
# # Create the map

# %%
import folium
import folium
from folium import Icon

def create_route_map(df_coordinates, df_routes):
    # Crear el mapa centrado en la primera ruta
    m = folium.Map(location=[df_coordinates['lat'].iloc[0], df_coordinates['lon'].iloc[0]], zoom_start=12.5)

    # Agregar puntos con un ícono de fuego y el texto con el índice
    for i, row in df_coordinates.iterrows():
        # Crear el texto con el índice
        popup_text = f'Orden: {i} - Falla: {row["Falla"]}'

        # Primer punto con un ícono de fuego de color azul
        if i == 0:
            folium.Marker(
                location=[row['lat'], row['lon']],
                icon=folium.Icon(icon="fire", prefix="fa", icon_color='blue'),
                popup=popup_text,
                tooltip=popup_text
            ).add_to(m)
        else:
            folium.Marker(
                location=[row['lat'], row['lon']],
                icon=folium.Icon(icon="fire", prefix="fa", icon_color='red'),
                popup=popup_text,
                tooltip=popup_text
            ).add_to(m)

    # Iterar sobre el GeoDataFrame y agregar cada ruta como PolyLine
    for idx, row in df_routes.iterrows():
        # Verificar si la geometría es un LineString válido
        if row['geometry'].geom_type == 'LineString':
            # Extraer las coordenadas de la geometría LineString y convertirla a una lista de tuplas
            coordinates = list(row['geometry'].coords)  # Lista de tuplas (lon, lat)
            
            # Agregar una PolyLine al mapa
            folium.PolyLine(locations=[[co[1], co[0]] for co in coordinates], color="blue", weight=2.5, opacity=1).add_to(m)

    return m

# Usar la función para crear el mapa con los datos de coordenadas y rutas
create_route_map(df_fallas, df_routes)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_36251096dba95007b6103a46f5f2abe1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_36251096dba95007b6103a46f5f2abe1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_36251096dba95007b6103a46f5f2abe1 = L.map(
#                 &quot;map_36251096dba95007b6103a46f5f2abe1&quot;,
#                 {
#                     center: [39.48868978996208, -0.3792881445677687],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12.5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c760797826136584d83a82271e0d3544 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c760797826136584d83a82271e0d3544.addTo(map_36251096dba95007b6103a46f5f2abe1);
#
#
#             var marker_1fa15560ff9571166345f35baccb2eb1 = L.marker(
#                 [39.48868978996208, -0.3792881445677687],
#                 {
# }
#             ).addTo(map_36251096dba95007b6103a46f5f2abe1);
#
#
#             var icon_91b32a9a7eff759a4efc657525eba8d5 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;blue&quot;,
#   &quot;icon&quot;: &quot;fire&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_5d43c16b8298cb8d59c0ced0b4ac4b38 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d5d5e6537310aabb0dff35da7b11b0a6 = $(`&lt;div id=&quot;html_d5d5e6537310aabb0dff35da7b11b0a6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Orden: 0 - Falla: Casa Luis&lt;/div&gt;`)[0];
#                 popup_5d43c16b8298cb8d59c0ced0b4ac4b38.setContent(html_d5d5e6537310aabb0dff35da7b11b0a6);
#
#
#
#         marker_1fa15560ff9571166345f35baccb2eb1.bindPopup(popup_5d43c16b8298cb8d59c0ced0b4ac4b38)
#         ;
#
#
#
#
#             marker_1fa15560ff9571166345f35baccb2eb1.bindTooltip(
#                 `&lt;div&gt;
#                      Orden: 0 - Falla: Casa Luis
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_1fa15560ff9571166345f35baccb2eb1.setIcon(icon_91b32a9a7eff759a4efc657525eba8d5);
#
#
#             var marker_0acea92d7a3003d7b2b50f59a20c8c59 = L.marker(
#                 [39.4927478, -0.3829761],
#                 {
# }
#             ).addTo(map_36251096dba95007b6103a46f5f2abe1);
#
#
#             var icon_bd443465ceea5b520a847e9e291ddfc7 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;red&quot;,
#   &quot;icon&quot;: &quot;fire&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_465f975f2a2199f3b82b68ac34d45245 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_50b915001cfdb39ad1caf4b881d36c3a = $(`&lt;div id=&quot;html_50b915001cfdb39ad1caf4b881d36c3a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Orden: 1 - Falla: Falla Gayano Lluch&lt;/div&gt;`)[0];
#                 popup_465f975f2a2199f3b82b68ac34d45245.setContent(html_50b915001cfdb39ad1caf4b881d36c3a);
#
#
#
#         marker_0acea92d7a3003d7b2b50f59a20c8c59.bindPopup(popup_465f975f2a2199f3b82b68ac34d45245)
#         ;
#
#
#
#
#             marker_0acea92d7a3003d7b2b50f59a20c8c59.bindTooltip(
#                 `&lt;div&gt;
#                      Orden: 1 - Falla: Falla Gayano Lluch
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_0acea92d7a3003d7b2b50f59a20c8c59.setIcon(icon_bd443465ceea5b520a847e9e291ddfc7);
#
#
#             var marker_26ba44d3c785576c2a978be590b70eb7 = L.marker(
#                 [39.483891, -0.3971927],
#                 {
# }
#             ).addTo(map_36251096dba95007b6103a46f5f2abe1);
#
#
#             var icon_68adfc158d98db9c441128ab7a4cc038 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;red&quot;,
#   &quot;icon&quot;: &quot;fire&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_65fcd7ae479747077f1ed05b0f334fc9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_97a6e32f73c951a42a74e0d7db2fc34b = $(`&lt;div id=&quot;html_97a6e32f73c951a42a74e0d7db2fc34b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Orden: 2 - Falla: Falla Monestir de Poblet – Aparicio Albiñana (L’Antiga de Campanar)&lt;/div&gt;`)[0];
#                 popup_65fcd7ae479747

# %%
import folium
import matplotlib.pyplot as plt
import numpy as np
from folium import Icon

def generate_color_palette(num_colors):
    """Genera una lista de colores de manera gradual"""
    colors = plt.cm.viridis(np.linspace(0, 1, num_colors))
    # Convertir los colores de rgba a hex
    return ['#%02x%02x%02x' % (int(r*255), int(g*255), int(b*255)) for r, g, b, a in colors]

def create_route_map(df_coordinates, df_routes):
    # Crear el mapa centrado en la primera ruta
    m = folium.Map(tiles='cartodbpositron', location=[df_coordinates['lat'].iloc[0], df_coordinates['lon'].iloc[0]], zoom_start=12.5)

    # Agregar puntos con un ícono de fuego y el texto con el índice
    for i, row in df_coordinates.iterrows():
        popup_text = f'Orden: {i} - Falla: {row["Falla"]}'

        # Primer punto con un ícono de fuego de color azul
        if i == 0:
            folium.Marker(
                location=[row['lat'], row['lon']],
                icon=folium.Icon(icon="fire", prefix="fa", icon_color='blue'),
                popup=popup_text,
                tooltip=popup_text
            ).add_to(m)
        else:
            folium.Marker(
                location=[row['lat'], row['lon']],
                icon=folium.Icon(icon="fire", prefix="fa", icon_color='red'),
                popup=popup_text,
                tooltip=popup_text
            ).add_to(m)

    # Generar la paleta de colores para las rutas
    num_routes = len(df_routes)
    color_palette = generate_color_palette(num_routes)

    # Iterar sobre el GeoDataFrame y agregar cada ruta como PolyLine
    for idx, row in df_routes.iterrows():
        if row['geometry'].geom_type == 'LineString':
            coordinates = list(row['geometry'].coords)  # Lista de tuplas (lon, lat)
            
            # Asignar un color de la paleta a esta ruta
            route_color = color_palette[idx]
            
            # Agregar una PolyLine al mapa con color gradual
            folium.PolyLine(
                locations=[[co[1], co[0]] for co in coordinates],
                color=route_color,
                weight=2.5,
                opacity=1
            ).add_to(m)

    return m

# Usar la función para crear el mapa con los datos de coordenadas y rutas
create_route_map(df_fallas, df_routes)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9aac3c7103d9d8e6355e96163a2b889d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9aac3c7103d9d8e6355e96163a2b889d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9aac3c7103d9d8e6355e96163a2b889d = L.map(
#                 &quot;map_9aac3c7103d9d8e6355e96163a2b889d&quot;,
#                 {
#                     center: [39.48868978996208, -0.3792881445677687],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12.5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_00611b02fba025f490d90c5dc8e7a44c = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_00611b02fba025f490d90c5dc8e7a44c.addTo(map_9aac3c7103d9d8e6355e96163a2b889d);
#
#
#             var marker_8e61981012f4bfa7ddf56eaa3e652320 = L.marker(
#                 [39.48868978996208, -0.3792881445677687],
#                 {
# }
#             ).addTo(map_9aac3c7103d9d8e6355e96163a2b889d);
#
#
#             var icon_5d2fc0de8bcabf0779e97d1b9db975e7 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;blue&quot;,
#   &quot;icon&quot;: &quot;fire&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_3aeb13721b681236287efd58aaada8e1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dbba18ea95233c6a5ce1fc65f14095a3 = $(`&lt;div id=&quot;html_dbba18ea95233c6a5ce1fc65f14095a3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Orden: 0 - Falla: Casa Luis&lt;/div&gt;`)[0];
#                 popup_3aeb13721b681236287efd58aaada8e1.setContent(html_dbba18ea95233c6a5ce1fc65f14095a3);
#
#
#
#         marker_8e61981012f4bfa7ddf56eaa3e652320.bindPopup(popup_3aeb13721b681236287efd58aaada8e1)
#         ;
#
#
#
#
#             marker_8e61981012f4bfa7ddf56eaa3e652320.bindTooltip(
#                 `&lt;div&gt;
#                      Orden: 0 - Falla: Casa Luis
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_8e61981012f4bfa7ddf56eaa3e652320.setIcon(icon_5d2fc0de8bcabf0779e97d1b9db975e7);
#
#
#             var marker_2f1443369c23cc3ebce62e362ca14f94 = L.marker(
#                 [39.4927478, -0.3829761],
#                 {
# }
#             ).addTo(map_9aac3c7103d9d8e6355e96163a2b889d);
#
#
#             var icon_c80487122750218707e32fd65fc7b658 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;red&quot;,
#   &quot;icon&quot;: &quot;fire&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_006c8b44e4da84b98fb86877c0d39a77 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_200ea2b80b8602d68b3840d61f78239e = $(`&lt;div id=&quot;html_200ea2b80b8602d68b3840d61f78239e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Orden: 1 - Falla: Falla Gayano Lluch&lt;/div&gt;`)[0];
#                 popup_006c8b44e4da84b98fb86877c0d39a77.setContent(html_200ea2b80b8602d68b3840d61f78239e);
#
#
#
#         marker_2f1443369c23cc3ebce62e362ca14f94.bindPopup(popup_006c8b44e4da84b98fb86877c0d39a77)
#         ;
#
#
#
#
#             marker_2f1443369c23cc3ebce62e362ca14f94.bindTooltip(
#                 `&lt;div&gt;
#                      Orden: 1 - Falla: Falla Gayano Lluch
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_2f1443369c23cc3ebce62e362ca14f94.setIcon(icon_c80487122750218707e32fd65fc7b658);
#
#
#             var marker_0937b87f8dd81d08b866e88e157fa664 = L.marker(
#                 [39.483891, -0.3971927],
#                 {
# }
#             ).addTo(map_9aac3c7103d9d8e6355e96163a2b889d);
#
#
#             var icon_23dd91fc4e0bd52862cd73ae7068d71c = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;red&quot;,
#   &quot;icon&quot;: &quot;fire&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_1d66af9473c2990b96b9c500b57d9e80 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_66d25fbd5070daf36c2c2f0dfa75e472 = $(`&lt;div id=&quot;html_66d25fbd5070daf36c2c2f0dfa75e472&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Orden: 2 - Falla: Falla Mone
