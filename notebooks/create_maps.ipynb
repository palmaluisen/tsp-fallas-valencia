# %%
# Load libraries
import pandas as pd

# %%
# Load datasets
df_routes = pd.read_csv('../data/df_routes_opt.csv')
df_routes.head()
# Out:
#                                                  ori  \
# 0                                  Estación del Nord
# 1                                 Falla Gayano Lluch
# 2  Falla Monestir de Poblet – Aparicio Albiñana (...
# 3                    Falla Quart-Extramurs-Velázquez
# 4                                   Falla Na Jordana
#
#                                                  des  osrm_dist  \
# 0                                 Falla Gayano Lluch      714.8
# 1  Falla Monestir de Poblet – Aparicio Albiñana (...     2031.6
# 2                    Falla Quart-Extramurs-Velázquez     2237.1
# 3                                   Falla Na Jordana     2757.2
# 4        Falla Reina-Paz-San Vicente (Falla Tio Pep)     1193.6
#
#                                       route_geometry
# 0  [[-0.377108, 39.467366], [-0.379316, 39.488637...
# 1  [[-0.382982, 39.492747], [-0.383104, 39.493083...
# 2  [[-0.397088, 39.483926], [-0.396998, 39.483797...
# 3  [[-0.407345, 39.472864], [-0.407455, 39.472843...
# 4  [[-0.38001, 39.480319], [-0.379891, 39.479779]...

# %%
df_fallas = pd.read_csv('../data/fallas.csv')
# Add start point
# Crear el nuevo registro
ayuntamiento = pd.DataFrame([{
    "Falla": "Estación del Nord",
    "Enlace": "https://www.google.com/maps/place/Ayuntamiento+de+Valencia/@39.4698068,-0.3771595,58m/data=!3m2!1e3!5s0xd604f4b7f4c477b:0x5596cd1cc0ee5fb8!4m6!3m5!1s0xd6048ad7bf45aab:0x2ba4baea5a36e1e2!8m2!3d39.4697956!4d-0.3770532!16s%2Fg%2F11cnp7lthl?entry=ttu&g_ep=EgoyMDI1MDMxMi4wIKXMDSoJLDEwMjExNDUzSAFQAw%3D%3D",
    "lat": 39.4674694952255,
    "lon": -0.3772975952898449
}])
df_fallas = pd.concat([ayuntamiento, df_fallas], ignore_index=True)
df_fallas
# Out:
#                                                 Falla  \
# 0                                   Estación del Nord
# 1          Falla Convento Jerusalén-Matemático Marzal
# 2                          Falla Cuba-Literato Azorín
# 3                         Falla Sueca-Literato Azorín
# 4              Falla Almirante Cadarso-Conde de Altea
# 5                                    Falla Na Jordana
# 6                               Falla Plaza del Pilar
# 7           Falla Regne de Valencia-Duque de Calabria
# 8                       Falla Exposición-Misser Mascó
# 9   Falla Monestir de Poblet – Aparicio Albiñana (...
# 10                Falla Duc de Gaeta-Pobla de Farnals
# 11                      Falla Espartero-Ramón y Cajal
# 12                                 Falla Gayano Lluch
# 13               Falla Maestro Gozalbo-Conde de Altea
# 14                       Falla Malvarrosa-Ponz-Cavite
# 15        Falla Reina-Paz-San Vicente (Falla Tio Pep)
# 16  Falla Conde de Salvatierra-Cirilo Amorós-Merca...
# 17                              Falla Císcar-Burriana
# 18                    Falla Plaza del Mercado Central
# 19         Falla Llanterna-Na Rovella-Avda. de l’Oest
# 20                           Falla Plaza de la Merced
# 21                                Falla Quart-Palomar
# 22                Falla Grabador Esteve-Cirilo Amorós
# 23                Falla San Vicente-Periodista Azzati
# 24                    Falla Quart-Extramurs-Velázquez
# 25             Falla Arzobispo Olaechea-San Marcelino
# 26              Falla Justo Vilar-Mercado del Cabañal
# 27          Falla Islas Canarias-Trafalgar-Samuel Ros
# 28                  Falla Ribera-Convento Santa Clara
# 29      Falla Jerónima Galés-Litógrafo Pascual y Abad
# 30  Falla Santa Genoveva Torres-Arquitecte Tolsà (...
#
#                                                Enlace        lat       lon
# 0   https://www.google.com/maps/place/Ayuntamiento...  39.467469 -0.377298
# 1   https://www.google.com/maps/place/Falla+Conven...  39.466441 -0.379912
# 2   https://www.google.com/maps/place/Falla+Cuba+L...  39.459464 -0.376410
# 3   https://www.google.com/maps/place/Falla+Sueca+...  39.460148 -0.376865
# 4   https://www.google.com/maps/place/Falla+Almira...  39.465822 -0.368480
# 5   https://www.google.com/maps/place/Falla+Na+Jor...  39.480291 -0.380225
# 6   https://www.google.com/maps/place/Falla+Plaza+...  39.471361 -0.383138
# 7   https://www.google.com/maps/place/A.C.+Falla+R...  39.463688 -0.366951
# 8   https://www.google.com/maps/place/Falla+Exposi...  39.475290 -0.361864
# 9   https://www.google.com/maps/place/Falla+Monest...  39.483891 -0.397193
# 10  https://www.google.com/maps/place/Asociaci%C3%...  39.468469 -0.350777
# 11  https://www.google.com/maps/place/Falla+Espart...  39.468113 -0.384829
# 12  https://www.google.com/maps/place/Falla+Gayano...  39.492748 -0.382976
# 13  https://www.google.com/maps/place/Falla+Maestr...  39.465336 -0.371728
# 14  https://www.google.com/maps/place/Falla+Malva-...  39.481039 -0.330545
# 15  https://www.google.com/maps/place/Falla+Tio+Pe...  39.471940 -0.378096
# 16  https://www.google.com/maps/place/A.C.+Falla+C...  39.468934 -0.370238
# 17  https://www.google.com/maps/place/Falla+Ciscar...  39.465254 -0.367803
# 18  https://www.google.com/maps/place/Falla+Pla%C3...  39.473543 -0.380622
# 19  https://www.google.com/maps/place/Falla+Llante...  39.472376 -0.383132
# 20  https://www.google.com/maps/place/Falla+Plaza+...  39.472757 -0.382729
# 21  https://www.google.com/maps/place/Falla+Quart+...  39.475314 -0.387408
# 22  https://www.google.com/maps/place/Falla+Grabad...  39.469506 -0.369120
# 23  https://www.google.com/maps/place/Falla+Sant+V...  39.469513 -0.380261
# 24  https://www.google.com/maps/place/Associaci%C3...  39.472837 -0.407336
# 25  https://www.google.com/maps/place/Casal+Falla+...  39.443569 -0.393223
# 26  https://www.google.com/maps/place/Falla+Just+V...  39.466941 -0.335761
# 27  https://www.google.com/maps/place/Falla+Islas+...  39.463735 -0.349270
# 28  https://www.google.com/maps/place/Falla+Ribera...  39.468609 -0.378505
# 29  https://www.google.com/maps/place/Falla+Jer%C3...  39.451783 -0.394889
# 30  https://www.google.com/maps/place/Falla+Santa+...  39.492751 -0.366055

# %%
import geopandas as gpd
import pandas as pd
import ast
from shapely.geometry import LineString

# Clean and convert the route_geometry column into a Python list (coordinates)
def create_line_string(geometry_str):
    try:
        # Remove any unwanted characters or spaces before parsing
        geometry_str_clean = geometry_str.strip()
        
        # Check if the string starts and ends with square brackets (list format)
        if geometry_str_clean.startswith('[') and geometry_str_clean.endswith(']'):
            # Safely convert string to list of coordinates
            coords = ast.literal_eval(geometry_str_clean)
            # Create a LineString geometry from the coordinates
            return LineString(coords)
        else:
            raise ValueError(f"Invalid geometry format: {geometry_str}")
    except (ValueError, SyntaxError, TypeError) as e:
        print(f"Error processing geometry: {e}")
        return None  # Return None for invalid geometries

def df_to_gdf(df, route_geometry_col='route_geometry'):


    # Apply the function to create the 'geometry' column containing LineString geometries
    df['geometry'] = df['route_geometry'].apply(create_line_string)

    # Now convert the DataFrame to a GeoDataFrame
    gdf_routes = gpd.GeoDataFrame(df, geometry='geometry')

    # Set the coordinate reference system (CRS) if known (for example, EPSG:4326 for WGS84)
    gdf_routes.set_crs('EPSG:4326', allow_override=True, inplace=True)

    return gdf_routes.drop(columns=[route_geometry_col])

# Check the GeoDataFrame
gdf_routes = df_to_gdf(df_routes)
gdf_routes.head()
# Out:
#                                                  ori  \
# 0                                  Estación del Nord
# 1                                 Falla Gayano Lluch
# 2  Falla Monestir de Poblet – Aparicio Albiñana (...
# 3                    Falla Quart-Extramurs-Velázquez
# 4                                   Falla Na Jordana
#
#                                                  des  osrm_dist  \
# 0                                 Falla Gayano Lluch      714.8
# 1  Falla Monestir de Poblet – Aparicio Albiñana (...     2031.6
# 2                    Falla Quart-Extramurs-Velázquez     2237.1
# 3                                   Falla Na Jordana     2757.2
# 4        Falla Reina-Paz-San Vicente (Falla Tio Pep)     1193.6
#
#                                             geometry
# 0  LINESTRING (-0.37711 39.46737, -0.37932 39.488...
# 1  LINESTRING (-0.38298 39.49275, -0.3831 39.4930...
# 2  LINESTRING (-0.39709 39.48393, -0.397 39.4838,...
# 3  LINESTRING (-0.40734 39.47286, -0.40746 39.472...
# 4  LINESTRING (-0.38001 39.48032, -0.37989 39.479...

# %%
df_fallas
# Out:
#                                                 Falla  \
# 0                                   Estación del Nord
# 1          Falla Convento Jerusalén-Matemático Marzal
# 2                          Falla Cuba-Literato Azorín
# 3                         Falla Sueca-Literato Azorín
# 4              Falla Almirante Cadarso-Conde de Altea
# 5                                    Falla Na Jordana
# 6                               Falla Plaza del Pilar
# 7           Falla Regne de Valencia-Duque de Calabria
# 8                       Falla Exposición-Misser Mascó
# 9   Falla Monestir de Poblet – Aparicio Albiñana (...
# 10                Falla Duc de Gaeta-Pobla de Farnals
# 11                      Falla Espartero-Ramón y Cajal
# 12                                 Falla Gayano Lluch
# 13               Falla Maestro Gozalbo-Conde de Altea
# 14                       Falla Malvarrosa-Ponz-Cavite
# 15        Falla Reina-Paz-San Vicente (Falla Tio Pep)
# 16  Falla Conde de Salvatierra-Cirilo Amorós-Merca...
# 17                              Falla Císcar-Burriana
# 18                    Falla Plaza del Mercado Central
# 19         Falla Llanterna-Na Rovella-Avda. de l’Oest
# 20                           Falla Plaza de la Merced
# 21                                Falla Quart-Palomar
# 22                Falla Grabador Esteve-Cirilo Amorós
# 23                Falla San Vicente-Periodista Azzati
# 24                    Falla Quart-Extramurs-Velázquez
# 25             Falla Arzobispo Olaechea-San Marcelino
# 26              Falla Justo Vilar-Mercado del Cabañal
# 27          Falla Islas Canarias-Trafalgar-Samuel Ros
# 28                  Falla Ribera-Convento Santa Clara
# 29      Falla Jerónima Galés-Litógrafo Pascual y Abad
# 30  Falla Santa Genoveva Torres-Arquitecte Tolsà (...
#
#                                                Enlace        lat       lon
# 0   https://www.google.com/maps/place/Ayuntamiento...  39.467469 -0.377298
# 1   https://www.google.com/maps/place/Falla+Conven...  39.466441 -0.379912
# 2   https://www.google.com/maps/place/Falla+Cuba+L...  39.459464 -0.376410
# 3   https://www.google.com/maps/place/Falla+Sueca+...  39.460148 -0.376865
# 4   https://www.google.com/maps/place/Falla+Almira...  39.465822 -0.368480
# 5   https://www.google.com/maps/place/Falla+Na+Jor...  39.480291 -0.380225
# 6   https://www.google.com/maps/place/Falla+Plaza+...  39.471361 -0.383138
# 7   https://www.google.com/maps/place/A.C.+Falla+R...  39.463688 -0.366951
# 8   https://www.google.com/maps/place/Falla+Exposi...  39.475290 -0.361864
# 9   https://www.google.com/maps/place/Falla+Monest...  39.483891 -0.397193
# 10  https://www.google.com/maps/place/Asociaci%C3%...  39.468469 -0.350777
# 11  https://www.google.com/maps/place/Falla+Espart...  39.468113 -0.384829
# 12  https://www.google.com/maps/place/Falla+Gayano...  39.492748 -0.382976
# 13  https://www.google.com/maps/place/Falla+Maestr...  39.465336 -0.371728
# 14  https://www.google.com/maps/place/Falla+Malva-...  39.481039 -0.330545
# 15  https://www.google.com/maps/place/Falla+Tio+Pe...  39.471940 -0.378096
# 16  https://www.google.com/maps/place/A.C.+Falla+C...  39.468934 -0.370238
# 17  https://www.google.com/maps/place/Falla+Ciscar...  39.465254 -0.367803
# 18  https://www.google.com/maps/place/Falla+Pla%C3...  39.473543 -0.380622
# 19  https://www.google.com/maps/place/Falla+Llante...  39.472376 -0.383132
# 20  https://www.google.com/maps/place/Falla+Plaza+...  39.472757 -0.382729
# 21  https://www.google.com/maps/place/Falla+Quart+...  39.475314 -0.387408
# 22  https://www.google.com/maps/place/Falla+Grabad...  39.469506 -0.369120
# 23  https://www.google.com/maps/place/Falla+Sant+V...  39.469513 -0.380261
# 24  https://www.google.com/maps/place/Associaci%C3...  39.472837 -0.407336
# 25  https://www.google.com/maps/place/Casal+Falla+...  39.443569 -0.393223
# 26  https://www.google.com/maps/place/Falla+Just+V...  39.466941 -0.335761
# 27  https://www.google.com/maps/place/Falla+Islas+...  39.463735 -0.349270
# 28  https://www.google.com/maps/place/Falla+Ribera...  39.468609 -0.378505
# 29  https://www.google.com/maps/place/Falla+Jer%C3...  39.451783 -0.394889
# 30  https://www.google.com/maps/place/Falla+Santa+...  39.492751 -0.366055

# %% [markdown]
# # Sort the fallas coordinates

# %%
df_fallas = pd.merge(df_fallas, gdf_routes["ori"], left_on='Falla',right_on="ori", how="right")
df_fallas.reset_index(drop=True, inplace=True)
df_fallas.head()
# Out:
#                                                Falla  \
# 0                                  Estación del Nord
# 1                                 Falla Gayano Lluch
# 2  Falla Monestir de Poblet – Aparicio Albiñana (...
# 3                    Falla Quart-Extramurs-Velázquez
# 4                                   Falla Na Jordana
#
#                                               Enlace        lat       lon  \
# 0  https://www.google.com/maps/place/Ayuntamiento...  39.467469 -0.377298
# 1  https://www.google.com/maps/place/Falla+Gayano...  39.492748 -0.382976
# 2  https://www.google.com/maps/place/Falla+Monest...  39.483891 -0.397193
# 3  https://www.google.com/maps/place/Associaci%C3...  39.472837 -0.407336
# 4  https://www.google.com/maps/place/Falla+Na+Jor...  39.480291 -0.380225
#
#                                                  ori
# 0                                  Estación del Nord
# 1                                 Falla Gayano Lluch
# 2  Falla Monestir de Poblet – Aparicio Albiñana (...
# 3                    Falla Quart-Extramurs-Velázquez
# 4                                   Falla Na Jordana

# %% [markdown]
# # Create the map

# %%
import folium
import folium
from folium import Icon

def create_route_map(df_coordinates, df_routes):
    # Crear el mapa centrado en la primera ruta
    m = folium.Map(location=[df_coordinates['lat'].iloc[0], df_coordinates['lon'].iloc[0]], zoom_start=12.5)

    # Agregar puntos con un ícono de fuego y el texto con el índice
    for i, row in df_coordinates.iterrows():
        # Crear el texto con el índice
        popup_text = f'Orden: {i} - Falla: {row["Falla"]}'

        # Primer punto con un ícono de fuego de color azul
        if i == 0:
            folium.Marker(
                location=[row['lat'], row['lon']],
                icon=folium.Icon(icon="fire", prefix="fa", icon_color='blue'),
                popup=popup_text,
                tooltip=popup_text
            ).add_to(m)
        else:
            folium.Marker(
                location=[row['lat'], row['lon']],
                icon=folium.Icon(icon="fire", prefix="fa", icon_color='red'),
                popup=popup_text,
                tooltip=popup_text
            ).add_to(m)

    # Iterar sobre el GeoDataFrame y agregar cada ruta como PolyLine
    for idx, row in df_routes.iterrows():
        # Verificar si la geometría es un LineString válido
        if row['geometry'].geom_type == 'LineString':
            # Extraer las coordenadas de la geometría LineString y convertirla a una lista de tuplas
            coordinates = list(row['geometry'].coords)  # Lista de tuplas (lon, lat)
            
            # Agregar una PolyLine al mapa
            folium.PolyLine(locations=[[co[1], co[0]] for co in coordinates], color="blue", weight=2.5, opacity=1).add_to(m)

    return m

# Usar la función para crear el mapa con los datos de coordenadas y rutas
create_route_map(df_fallas, df_routes)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5d97b9ff7c4cdd722e8c0bafa486df22 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5d97b9ff7c4cdd722e8c0bafa486df22&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5d97b9ff7c4cdd722e8c0bafa486df22 = L.map(
#                 &quot;map_5d97b9ff7c4cdd722e8c0bafa486df22&quot;,
#                 {
#                     center: [39.4674694952255, -0.3772975952898449],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12.5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bbaae3880ee0b61c98ac1e3aab5a77f2 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_bbaae3880ee0b61c98ac1e3aab5a77f2.addTo(map_5d97b9ff7c4cdd722e8c0bafa486df22);
#
#
#             var marker_53c86337882b903ed35cd9abd977c3a4 = L.marker(
#                 [39.4674694952255, -0.3772975952898449],
#                 {
# }
#             ).addTo(map_5d97b9ff7c4cdd722e8c0bafa486df22);
#
#
#             var icon_2cd019479d84cbb027d32abe9eda3cd3 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;blue&quot;,
#   &quot;icon&quot;: &quot;fire&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_9a24d196660cd17ee5dde8cc4e0e53fb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_90c9dcc183b242b2ddf26c17d19090b5 = $(`&lt;div id=&quot;html_90c9dcc183b242b2ddf26c17d19090b5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Orden: 0 - Falla: Estación del Nord&lt;/div&gt;`)[0];
#                 popup_9a24d196660cd17ee5dde8cc4e0e53fb.setContent(html_90c9dcc183b242b2ddf26c17d19090b5);
#
#
#
#         marker_53c86337882b903ed35cd9abd977c3a4.bindPopup(popup_9a24d196660cd17ee5dde8cc4e0e53fb)
#         ;
#
#
#
#
#             marker_53c86337882b903ed35cd9abd977c3a4.bindTooltip(
#                 `&lt;div&gt;
#                      Orden: 0 - Falla: Estación del Nord
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_53c86337882b903ed35cd9abd977c3a4.setIcon(icon_2cd019479d84cbb027d32abe9eda3cd3);
#
#
#             var marker_d87545a4b4353431a1354794e8528272 = L.marker(
#                 [39.4927478, -0.3829761],
#                 {
# }
#             ).addTo(map_5d97b9ff7c4cdd722e8c0bafa486df22);
#
#
#             var icon_6418df44312064f8cfe2124bffb61ce7 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;red&quot;,
#   &quot;icon&quot;: &quot;fire&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_c198addeee9d63c2cb96adae9a20cd9f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1d619696083e2d2daf1721e94eed3bc4 = $(`&lt;div id=&quot;html_1d619696083e2d2daf1721e94eed3bc4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Orden: 1 - Falla: Falla Gayano Lluch&lt;/div&gt;`)[0];
#                 popup_c198addeee9d63c2cb96adae9a20cd9f.setContent(html_1d619696083e2d2daf1721e94eed3bc4);
#
#
#
#         marker_d87545a4b4353431a1354794e8528272.bindPopup(popup_c198addeee9d63c2cb96adae9a20cd9f)
#         ;
#
#
#
#
#             marker_d87545a4b4353431a1354794e8528272.bindTooltip(
#                 `&lt;div&gt;
#                      Orden: 1 - Falla: Falla Gayano Lluch
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_d87545a4b4353431a1354794e8528272.setIcon(icon_6418df44312064f8cfe2124bffb61ce7);
#
#
#             var marker_8a35763e2ea580f805214f54f9cb4b46 = L.marker(
#                 [39.483891, -0.3971927],
#                 {
# }
#             ).addTo(map_5d97b9ff7c4cdd722e8c0bafa486df22);
#
#
#             var icon_d8a2be0f0615912d271fe4f0cbcc4dcf = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;red&quot;,
#   &quot;icon&quot;: &quot;fire&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_c5256de7090c682486cec6abf8a484d9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c484994276a128d6334acd42566fcd66 = $(`&lt;div id=&quot;html_c484994276a128d6334acd42566fcd66&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Orden: 2 - Falla: Falla Monestir de Poblet – Aparicio Albiñana (L’Antiga de Campanar)&lt;/div&gt;`)[0];
#                 popup_

# %%
import folium
import matplotlib.pyplot as plt
import numpy as np
from folium import Icon

def generate_color_palette(num_colors):
    """Genera una lista de colores de manera gradual"""
    colors = plt.cm.viridis(np.linspace(0, 1, num_colors))
    # Convertir los colores de rgba a hex
    return ['#%02x%02x%02x' % (int(r*255), int(g*255), int(b*255)) for r, g, b, a in colors]

def create_route_map(df_coordinates, df_routes):
    # Crear el mapa centrado en la primera ruta
    m = folium.Map(tiles='cartodbpositron', location=[df_coordinates['lat'].iloc[0], df_coordinates['lon'].iloc[0]], zoom_start=12.5)

    # Agregar puntos con un ícono de fuego y el texto con el índice
    for i, row in df_coordinates.iterrows():
        popup_text = f'Orden: {i} - Falla: {row["Falla"]}'

        # Primer punto con un ícono de fuego de color azul
        if i == 0:
            folium.Marker(
                location=[row['lat'], row['lon']],
                icon=folium.Icon(icon="fire", prefix="fa", icon_color='blue'),
                popup=popup_text,
                tooltip=popup_text
            ).add_to(m)
        else:
            folium.Marker(
                location=[row['lat'], row['lon']],
                icon=folium.Icon(icon="fire", prefix="fa", icon_color='red'),
                popup=popup_text,
                tooltip=popup_text
            ).add_to(m)

    # Generar la paleta de colores para las rutas
    num_routes = len(df_routes)
    color_palette = generate_color_palette(num_routes)

    # Iterar sobre el GeoDataFrame y agregar cada ruta como PolyLine
    for idx, row in df_routes.iterrows():
        if row['geometry'].geom_type == 'LineString':
            coordinates = list(row['geometry'].coords)  # Lista de tuplas (lon, lat)
            
            # Asignar un color de la paleta a esta ruta
            route_color = color_palette[idx]
            
            # Agregar una PolyLine al mapa con color gradual
            folium.PolyLine(
                locations=[[co[1], co[0]] for co in coordinates],
                color=route_color,
                weight=2.5,
                opacity=1
            ).add_to(m)

    return m

# Usar la función para crear el mapa con los datos de coordenadas y rutas
create_route_map(df_fallas, df_routes)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_89546844bc3ac767a2a6bc9582e02096 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_89546844bc3ac767a2a6bc9582e02096&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_89546844bc3ac767a2a6bc9582e02096 = L.map(
#                 &quot;map_89546844bc3ac767a2a6bc9582e02096&quot;,
#                 {
#                     center: [39.4674694952255, -0.3772975952898449],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12.5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_49d46281baa71e6ae3dd7a29840d2756 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_49d46281baa71e6ae3dd7a29840d2756.addTo(map_89546844bc3ac767a2a6bc9582e02096);
#
#
#             var marker_590720b921df4f42f29259ad25b63ac5 = L.marker(
#                 [39.4674694952255, -0.3772975952898449],
#                 {
# }
#             ).addTo(map_89546844bc3ac767a2a6bc9582e02096);
#
#
#             var icon_3eb161f1af8a18fabb57c1033788248e = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;blue&quot;,
#   &quot;icon&quot;: &quot;fire&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_d81681b145e331f11d25a33e08dcc591 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_22f6fd1bfddafa1ef6fc748b203ddcaa = $(`&lt;div id=&quot;html_22f6fd1bfddafa1ef6fc748b203ddcaa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Orden: 0 - Falla: Estación del Nord&lt;/div&gt;`)[0];
#                 popup_d81681b145e331f11d25a33e08dcc591.setContent(html_22f6fd1bfddafa1ef6fc748b203ddcaa);
#
#
#
#         marker_590720b921df4f42f29259ad25b63ac5.bindPopup(popup_d81681b145e331f11d25a33e08dcc591)
#         ;
#
#
#
#
#             marker_590720b921df4f42f29259ad25b63ac5.bindTooltip(
#                 `&lt;div&gt;
#                      Orden: 0 - Falla: Estación del Nord
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_590720b921df4f42f29259ad25b63ac5.setIcon(icon_3eb161f1af8a18fabb57c1033788248e);
#
#
#             var marker_234d536e5790b93f4890758462739346 = L.marker(
#                 [39.4927478, -0.3829761],
#                 {
# }
#             ).addTo(map_89546844bc3ac767a2a6bc9582e02096);
#
#
#             var icon_f39221ffc47effd6a87e6192842b03d7 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;red&quot;,
#   &quot;icon&quot;: &quot;fire&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_90bc8541a2057e83b2f36129b43d5061 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e12e397bfd773cea98ecf571652ea904 = $(`&lt;div id=&quot;html_e12e397bfd773cea98ecf571652ea904&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Orden: 1 - Falla: Falla Gayano Lluch&lt;/div&gt;`)[0];
#                 popup_90bc8541a2057e83b2f36129b43d5061.setContent(html_e12e397bfd773cea98ecf571652ea904);
#
#
#
#         marker_234d536e5790b93f4890758462739346.bindPopup(popup_90bc8541a2057e83b2f36129b43d5061)
#         ;
#
#
#
#
#             marker_234d536e5790b93f4890758462739346.bindTooltip(
#                 `&lt;div&gt;
#                      Orden: 1 - Falla: Falla Gayano Lluch
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_234d536e5790b93f4890758462739346.setIcon(icon_f39221ffc47effd6a87e6192842b03d7);
#
#
#             var marker_723b59baa5b3ccd4e5486c8134abe49e = L.marker(
#                 [39.483891, -0.3971927],
#                 {
# }
#             ).addTo(map_89546844bc3ac767a2a6bc9582e02096);
#
#
#             var icon_29754a593894e25e70ffc821461bf985 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;red&quot;,
#   &quot;icon&quot;: &quot;fire&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_769906a9a116d905fe9c474cc3fa4c09 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a0a451467e55ad8ec7aeb30585a8914c = $(`&lt;div id=&quot;html_a0a451467e55ad8ec7aeb30585a8914c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Orden: 2 - Fal
